# %% [markdown]
# ## **LSTM Grid Search for Crypto Lending and Borrowing Rates**
#
# **1. Merging with Market Cap Data:** We read the market capitalization data from a CSV file and merge it with the previously fetched cryptocurrency data based on the date and crypto symbol. This ensures that our dataset includes both the financial metrics and the market cap for each cryptocurrency.
#
# **2. Data Cleaning and Preparation:** We clean the merged dataset by removing rows with missing market cap values and resetting the index. We also create embeddings and cyclical encodings for the crypto symbols and date features to prepare the data for the LSTM model.
#
# **3. Filtering and Scaling Data:** We filter the dataset to remove rows with placeholder values and calculate an attention metric. We then scale the relevant features (market cap, attention, yield) using MinMaxScaler to ensure they are on a comparable scale.
#
# **4. Defining Input and Output Windows:** We define the input and output windows for the LSTM model, specifying the columns to be used as inputs. This includes various financial metrics, embeddings, and cyclical encodings.
#
# **5. Extracting Valid Windows:** We loop through each cryptocurrency symbol to calculate intervals for each column and filter rows based on these intervals. We then calculate hourly returns and scale the data before extracting valid input and output windows for the LSTM model.
#
# **6. Training the LSTM Model:** We initialize empty lists to store aggregated inputs and targets, and concatenate them into single arrays. We then train the LSTM model using the extracted input and output windows, and evaluate its performance using various metrics such as accuracy, precision, recall, and F1 score.
#
# **7. Performing Grid Search:** We perform a grid search on the base architecture of the LSTM model, experimenting with different combinations of input and output windows, and outlier thresholds. We store the results of each combination in a DataFrame and save them to CSV files.
#
# **8. Analyzing Results:** We concatenate the results from the grid search and save them to an Excel file. We also calculate the correlation between various parameters (total windows, input window, output window) and accuracy, and create scatter plots with regression lines to visualize these correlations.

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sentence_transformers import SentenceTransformer
import mysql.connector
from mysql.connector import Error
import pandas as pd
from mysql.connector import Error
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
import seaborn as sns
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Masking, Reshape, Layer, Lambda, Concatenate, LayerNormalization, MultiHeadAttention
from tensorflow.keras.models import Model
from tensorflow.keras import backend as be
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adadelta
from keras.layers import BatchNormalization
from keras.regularizers import l2
import matplotlib.pyplot as plt
import utils as pre
import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
connection = pre.connect_to_database()
if connection:
    # Query merged data
    merged_df = pre.query_merged_crypto_data(connection)
    # converting US bond yield from hourly to yearly under continous compounding assumptions
    merged_df['yield'] = np.exp(merged_df['yield']*365*24)-1

    # Close the connection
    pre.query_quit(connection)

merged_df.head(3)
# Out:
# Connected to MySQL database, MySQL Server version:  8.0.39
# MySQL connection is closed
#   lending_rate borrowing_rate utilization_rate stable_borrow_rate  \
# 0   -50.000000     -50.000000       -50.000000           0.030000
# 1   -50.000000     -50.000000       -50.000000           0.030000
# 2   -50.000000     -50.000000         0.013598           0.030000
#
#   crypto_symbol                date  high   low close adj_close   volume  \
# 0       BATUSDT 2020-12-02 14:00:00  0.24  0.24  0.24      0.24  1294545
# 1       BATUSDT 2020-12-02 15:00:00  0.24  0.24  0.24      0.24   936344
# 2       BATUSDT 2020-12-02 16:00:00  0.24  0.24  0.24      0.24   724626
#
#   market_cap coin_supply                          yield
# 0       None        None  0.008552840317602313182744400
# 1       None        None  0.008552840317602313182744400
# 2       None        None  0.008552840317602313182744400

# %% [markdown]
# ### merging with market cap

# %%
market_caps = pd.read_csv('market_cap_data.csv')
market_caps = market_caps.rename(columns={
    'timestamp': 'date',
    'token': 'crypto_symbol',
})
market_caps.head(3)
# Out:
#    Unnamed: 0                 date  market_cap crypto_symbol
# 0           0  2020-12-21 00:00:00    87121414     1INCHUSDT
# 1           1  2020-12-21 01:00:00    87121414     1INCHUSDT
# 2           2  2020-12-21 02:00:00    87121414     1INCHUSDT

# %%
# Convert 'date' columns to pandas datetime format
merged_df['date'] = pd.to_datetime(merged_df['date'])
market_caps['date'] = pd.to_datetime(market_caps['date'])

# Perform the merge based on 'crypto_symbol' and 'date', keeping only rows in merged_df
merged_df.drop('market_cap', axis = 1, inplace=True)
merged_df = pd.merge(
    merged_df,
    market_caps[['date', 'market_cap', 'crypto_symbol']],
    on=['date', 'crypto_symbol'],
    how='left'
)

merged_df.head(3)
# Out:
#   lending_rate borrowing_rate utilization_rate stable_borrow_rate  \
# 0   -50.000000     -50.000000       -50.000000           0.030000
# 1   -50.000000     -50.000000       -50.000000           0.030000
# 2   -50.000000     -50.000000         0.013598           0.030000
#
#   crypto_symbol                date  high   low close adj_close   volume  \
# 0       BATUSDT 2020-12-02 14:00:00  0.24  0.24  0.24      0.24  1294545
# 1       BATUSDT 2020-12-02 15:00:00  0.24  0.24  0.24      0.24   936344
# 2       BATUSDT 2020-12-02 16:00:00  0.24  0.24  0.24      0.24   724626
#
#   coin_supply                          yield   market_cap
# 0        None  0.008552840317602313182744400  317700843.0
# 1        None  0.008552840317602313182744400  317700843.0
# 2        None  0.008552840317602313182744400  317700843.0

# %%
# KNC has wrong data before 2021
merged_df = merged_df[merged_df['market_cap'].notna()]
merged_df.reset_index(inplace = True, drop=True)

# %%
# embeddings and time features
merged_df_emb = pre.create_llm_embeddings(merged_df, "crypto_symbol", n_components=15)
merged_df_emb = pre.create_cyclical_encodings(merged_df_emb, "date")

# %%
# data without NA rows if we needed 
filtered_df = merged_df_emb[(merged_df['borrowing_rate'] != -50)&(merged_df['lending_rate'] != -50)&(merged_df['utilization_rate'] != -50)]
filtered_df['attention'] = filtered_df['volume'] * filtered_df['close']
filtered_df.drop(columns=['stable_borrow_rate','adj_close','coin_supply'], inplace=True)
filtered_df[['lending_rate','borrowing_rate','utilization_rate','close', 'volume']] = filtered_df[['lending_rate','borrowing_rate','utilization_rate','close', 'volume']].astype(float)
filtered_df.reset_index(inplace=True, drop=True)
print(len(filtered_df))
filtered_df.columns
# Out:
# 413705
# Index(['lending_rate', 'borrowing_rate', 'utilization_rate', 'crypto_symbol',
#        'date', 'high', 'low', 'close', 'volume', 'yield', 'market_cap',
#        'crypto_symbol_embedding_1', 'crypto_symbol_embedding_2',
#        'crypto_symbol_embedding_3', 'crypto_symbol_embedding_4',
#        'crypto_symbol_embedding_5', 'crypto_symbol_embedding_6',
#        'crypto_symbol_embedding_7', 'crypto_symbol_embedding_8',
#        'crypto_symbol_embedding_9', 'crypto_symbol_embedding_10',
#        'crypto_symbol_embedding_11', 'crypto_symbol_embedding_12',
#        'crypto_symbol_embedding_13', 'crypto_symbol_embedding_14',
#        'crypto_symbol_embedding_15', 'Month_Sine', 'Month_Cosine', 'Day_Sine',
#        'Day_Cosine', 'Hour_Sine', 'Hour_Cosine', 'DayofWeek_Sine',
#        'DayofWeek_Cosine', 'attention'],
#       dtype='object')

# %%
# We scale  market cap, attention, yield together as they are comparable
scaler = MinMaxScaler(feature_range=(0, 1))  # Default range is (0, 1)
filtered_df['yield'] = scaler.fit_transform(filtered_df[['yield']])
filtered_df['market_cap'] = scaler.fit_transform(filtered_df[['market_cap']])
filtered_df['attention'] = scaler.fit_transform(filtered_df[['attention']])

# %%
outlier_threshold = 1.5
input_window = 48
output_window = 24
input_columns = ['lending_rate', 'borrowing_rate', 'utilization_rate',
                 'close', 'volume', 'yield', 'market_cap',
       'crypto_symbol_embedding_1', 'crypto_symbol_embedding_2',
       'crypto_symbol_embedding_3', 'crypto_symbol_embedding_4',
       'crypto_symbol_embedding_5', 'crypto_symbol_embedding_6',
       'crypto_symbol_embedding_7', 'crypto_symbol_embedding_8',
       'crypto_symbol_embedding_9', 'crypto_symbol_embedding_10',
       'crypto_symbol_embedding_11', 'crypto_symbol_embedding_12',
       'crypto_symbol_embedding_13', 'crypto_symbol_embedding_14',
       'crypto_symbol_embedding_15', 'Month_Sine', 'Month_Cosine', 'Day_Sine',
       'Day_Cosine', 'Hour_Sine', 'Hour_Cosine', 'DayofWeek_Sine',
       'DayofWeek_Cosine', 'attention','returns']

# %%
# Initialize empty lists to store aggregated inputs and targets
all_inputs = []
all_targets = []

# looping through symbols
symbols = filtered_df['crypto_symbol'].unique()
for s in symbols:
     try:
          sim_df = filtered_df[filtered_df['crypto_symbol'] == s]
          sim_df.reset_index(inplace=True, drop=True)
          print(s, len(sim_df))
          # First Loop: Calculate intervals for each column without modifying the DataFrame
          intervals = {}
          for column in ['lending_rate', 'borrowing_rate', 'utilization_rate']:
               lower, upper = pre.calculate_iqr_bounds(sim_df[column],outlier_threshold)
               intervals[column] = {'lower_bound': lower, 'upper_bound': upper}

          # getting the returns
          reduced_df = sim_df.copy()
          reduced_df['returns'] = pre.calculate_hourly_returns(reduced_df, 'date', 'close')
          reduced_df = reduced_df[reduced_df['returns'].notna()]
          print('rows with valid returns:', len(reduced_df))
          reduced_df.reset_index(inplace=True, drop=True)

          # Second Loop: Filter rows based on the pre-calculated intervals
          for column in ['lending_rate', 'borrowing_rate', 'utilization_rate']:
               lower_bound = intervals[column]['lower_bound']
               upper_bound = intervals[column]['upper_bound']
               # Apply filtering based on pre-calculated bounds
               reduced_df = reduced_df[(reduced_df[column] > lower_bound) & (reduced_df[column] < upper_bound)]

          reduced_df.reset_index(inplace=True, drop=True)

          # MinMax scaling
          scaler = MinMaxScaler(feature_range=(0, 1))  # Default range is (0, 1)

          scaled_df = reduced_df.copy()
          scaled_df['lending_rate'] = scaler.fit_transform(reduced_df[['lending_rate']])
          scaled_df['borrowing_rate'] = scaler.fit_transform(reduced_df[['borrowing_rate']])
          scaled_df['utilization_rate'] = scaler.fit_transform(reduced_df[['utilization_rate']])
          scaled_df['close'] = scaler.fit_transform(reduced_df[['close']])
          scaled_df['volume'] = scaler.fit_transform(reduced_df[['volume']])
          scaled_df['returns'] = scaler.fit_transform(reduced_df[['returns']])

          inputs, targets = pre.extract_valid_windows_v2(
               scaled_df,
               'date', 
               input_window, output_window, 
               input_columns, 
               ['lending_rate','borrowing_rate']
               )

          # Append results from the current DataFrame
          all_inputs.append(inputs)
          all_targets.append(targets)

          print('input size', inputs.shape)
          print('output size', targets.shape)

     except Exception as e:
        # Handle any other exceptions
        print(f"Unexpected error in symbol {s}: {e}")
# Out:
# BATUSDT 28159
# rows with valid returns: 27850
# input size (10222, 48, 32)
# output size (10222, 2)
# LINKUSDT 31934
# rows with valid returns: 31598
# input size (8765, 48, 32)
# output size (8765, 2)
# KNCUSDT 22745
# rows with valid returns: 22652
# input size (3189, 48, 32)
# output size (3189, 2)
# MKRUSDT 30094
# rows with valid returns: 29657
# input size (7645, 48, 32)
# output size (7645, 2)
# MANAUSDT 27145
# rows with valid returns: 26560
# input size (2858, 48, 32)
# output size (2858, 2)
# ZRXUSDT 28255
# rows with valid returns: 28057
# input size (11747, 48, 32)
# output size (11747, 2)
# SNXUSDT 31087
# rows with valid returns: 30477
# input size (4984, 48, 32)
# output size (4984, 2)
# WBTCUSDT 11729
# rows with valid returns: 11297
# input size (244, 48, 32)
# output size (244, 2)
# ENJUSDT 27034
# rows with valid returns: 26606
# input size (7331, 48, 32)
# output size (7331, 2)
# RENUSDT 27658
# rows with valid returns: 27296
# input size (7834, 48, 32)
# output size (7834, 2)
# YFIUSDT 29900
# rows with valid returns: 29426
# input size (2856, 48, 32)
# output size (2856, 2)
# UNIUSDT 29885
# rows with valid returns: 29300
# input size (3954, 48, 32)
# output size (3954, 2)
# CRVUSDT 28455
# rows with valid returns: 27458
# input size (1004, 48, 32)
# output size (1004, 2)
# BALUSDT 24855
# rows with valid returns: 24317
# input size (1741, 48, 32)
# output size (1741, 2)
# ENSUSDT 20745
# rows with valid returns: 20574
# input size (6319, 48, 32)
# output size (6319, 2)
# 1INCHUSDT 14025
# rows with valid returns: 13930
# input size (4217, 48, 32)
# output size (4217, 2)

# %%
# Concatenate all inputs and targets into single arrays
all_inputs = np.concatenate(all_inputs, axis=0) if all_inputs else np.array([])
all_targets = np.concatenate(all_targets, axis=0) if all_targets else np.array([])
print('total input size', all_inputs.shape)
print('total output size', all_targets.shape)
# Out:
# total input size (84910, 48, 32)
# total output size (84910, 2)

# %%
# Lending rate
output_1 = all_targets[:, 0].reshape(all_targets.shape[0], 1) 
# Borrowing rate
output_2 = all_targets[:, 1].reshape(all_targets.shape[0], 1) 
print(output_1.shape) 
print(output_2.shape)
# Out:
# (84910, 1)
# (84910, 1)

# %%
# sample model
y_test, y_pred = pre.train_v1(all_inputs, output_1)
# Out:
# Epoch 1/100
# 255/255 [==============================] - 23s 71ms/step - loss: 0.7819 - accuracy: 0.6607 - val_loss: 0.6908 - val_accuracy: 0.7006
# Epoch 2/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.6422 - accuracy: 0.7214 - val_loss: 0.6045 - val_accuracy: 0.7352
# Epoch 3/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.5943 - accuracy: 0.7415 - val_loss: 0.5538 - val_accuracy: 0.7619
# Epoch 4/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.5558 - accuracy: 0.7592 - val_loss: 0.5245 - val_accuracy: 0.7742
# Epoch 5/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.5230 - accuracy: 0.7741 - val_loss: 0.4957 - val_accuracy: 0.7904
# Epoch 6/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.4952 - accuracy: 0.7884 - val_loss: 0.4732 - val_accuracy: 0.7957
# Epoch 7/100
# 255/255 [==============================] - 18s 69ms/step - loss: 0.4715 - accuracy: 0.7981 - val_loss: 0.4456 - val_accuracy: 0.8116
# Epoch 8/100
# 255/255 [==============================] - 18s 69ms/step - loss: 0.4494 - accuracy: 0.8094 - val_loss: 0.4420 - val_accuracy: 0.8130
# Epoch 9/100
# 255/255 [==============================] - 18s 69ms/step - loss: 0.4303 - accuracy: 0.8196 - val_loss: 0.4138 - val_accuracy: 0.8266
# Epoch 10/100
# 255/255 [==============================] - 18s 69ms/step - loss: 0.4152 - accuracy: 0.8265 - val_loss: 0.4147 - val_accuracy: 0.8235
# Epoch 11/100
# 255/255 [==============================] - 18s 69ms/step - loss: 0.3985 - accuracy: 0.8342 - val_loss: 0.3919 - val_accuracy: 0.8401
# Epoch 12/100
# 255/255 [==============================] - 18s 69ms/step - loss: 0.3872 - accuracy: 0.8393 - val_loss: 0.3826 - val_accuracy: 0.8447
# Epoch 13/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.3729 - accuracy: 0.8471 - val_loss: 0.3719 - val_accuracy: 0.8502
# Epoch 14/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.3613 - accuracy: 0.8515 - val_loss: 0.3690 - val_accuracy: 0.8518
# Epoch 15/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.3494 - accuracy: 0.8577 - val_loss: 0.3536 - val_accuracy: 0.8597
# Epoch 16/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.3431 - accuracy: 0.8610 - val_loss: 0.3464 - val_accuracy: 0.8616
# Epoch 17/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.3375 - accuracy: 0.8626 - val_loss: 0.3447 - val_accuracy: 0.8636
# Epoch 18/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.3265 - accuracy: 0.8684 - val_loss: 0.3293 - val_accuracy: 0.8714
# Epoch 19/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.3182 - accuracy: 0.8737 - val_loss: 0.3271 - val_accuracy: 0.8755
# Epoch 20/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.3128 - accuracy: 0.8743 - val_loss: 0.3180 - val_accuracy: 0.8769
# Epoch 21/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.3092 - accuracy: 0.8767 - val_loss: 0.3215 - val_accuracy: 0.8770
# Epoch 22/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.3026 - accuracy: 0.8785 - val_loss: 0.3093 - val_accuracy: 0.8813
# Epoch 23/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2948 - accuracy: 0.8812 - val_loss: 0.3053 - val_accuracy: 0.8838
# Epoch 24/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2886 - accuracy: 0.8861 - val_loss: 0.3138 - val_accuracy: 0.8841
# Epoch 25/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2840 - accuracy: 0.8882 - val_loss: 0.3008 - val_accuracy: 0.8868
# Epoch 26/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2802 - accuracy: 0.8874 - val_loss: 0.3019 - val_accuracy: 0.8869
# Epoch 27/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2728 - accuracy: 0.8918 - val_loss: 0.2978 - val_accuracy: 0.8904
# Epoch 28/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2701 - accuracy: 0.8939 - val_loss: 0.2945 - val_accuracy: 0.8898
# Epoch 29/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2645 - accuracy: 0.8959 - val_loss: 0.2944 - val_accuracy: 0.8892
# Epoch 30/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2619 - accuracy: 0.8967 - val_loss: 0.2777 - val_accuracy: 0.8964
# Epoch 31/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2565 - accuracy: 0.8970 - val_loss: 0.2910 - val_accuracy: 0.8932
# Epoch 32/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2539 - accuracy: 0.8995 - val_loss: 0.2851 - val_accuracy: 0.8938
# Epoch 33/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2498 - accuracy: 0.9018 - val_loss: 0.2842 - val_accuracy: 0.8940
# Epoch 34/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2436 - accuracy: 0.9052 - val_loss: 0.2797 - val_accuracy: 0.8992
# Epoch 35/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2407 - accuracy: 0.9046 - val_loss: 0.2693 - val_accuracy: 0.9018
# Epoch 36/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2380 - accuracy: 0.9060 - val_loss: 0.2796 - val_accuracy: 0.8969
# Epoch 37/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2341 - accuracy: 0.9080 - val_loss: 0.2762 - val_accuracy: 0.8981
# Epoch 38/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2320 - accuracy: 0.9093 - val_loss: 0.2769 - val_accuracy: 0.9008
# Epoch 39/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2291 - accuracy: 0.9102 - val_loss: 0.2760 - val_accuracy: 0.9006
# Epoch 40/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2237 - accuracy: 0.9127 - val_loss: 0.2840 - val_accuracy: 0.8995
# Epoch 41/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2224 - accuracy: 0.9124 - val_loss: 0.2707 - val_accuracy: 0.9020
# Epoch 42/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.2203 - accuracy: 0.9138 - val_loss: 0.2686 - val_accuracy: 0.9039
# Epoch 43/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2208 - accuracy: 0.9131 - val_loss: 0.2689 - val_accuracy: 0.9039
# Epoch 44/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2157 - accuracy: 0.9153 - val_loss: 0.2659 - val_accuracy: 0.9055
# Epoch 45/100
# 255/255 [==============================] - 17s 65ms/step - loss: 0.2128 - accuracy: 0.9158 - val_loss: 0.2682 - val_accuracy: 0.9060
# Epoch 46/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.2126 - accuracy: 0.9155 - val_loss: 0.2694 - val_accuracy: 0.9061
# Epoch 47/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2088 - accuracy: 0.9187 - val_loss: 0.2708 - val_accuracy: 0.9035
# Epoch 48/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2058 - accuracy: 0.9202 - val_loss: 0.2613 - val_accuracy: 0.9078
# Epoch 49/100
# 255/255 [==============================] - 17s 65ms/step - loss: 0.2028 - accuracy: 0.9216 - val_loss: 0.2699 - val_accuracy: 0.9055
# Epoch 50/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.2025 - accuracy: 0.9218 - val_loss: 0.2613 - val_accuracy: 0.9098
# Epoch 51/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1971 - accuracy: 0.9225 - val_loss: 0.2620 - val_accuracy: 0.9109
# Epoch 52/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1981 - accuracy: 0.9231 - val_loss: 0.2646 - val_accuracy: 0.9092
# Epoch 53/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.1961 - accuracy: 0.9227 - val_loss: 0.2591 - val_accuracy: 0.9117
# Epoch 54/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.1939 - accuracy: 0.9243 - val_loss: 0.2554 - val_accuracy: 0.9125
# Epoch 55/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1913 - accuracy: 0.9258 - val_loss: 0.2584 - val_accuracy: 0.9122
# Epoch 56/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1887 - accuracy: 0.9262 - val_loss: 0.2740 - val_accuracy: 0.9066
# Epoch 57/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1874 - accuracy: 0.9275 - val_loss: 0.2661 - val_accuracy: 0.9088
# Epoch 58/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1895 - accuracy: 0.9265 - val_loss: 0.2574 - val_accuracy: 0.9130
# Epoch 59/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1868 - accuracy: 0.9275 - val_loss: 0.2628 - val_accuracy: 0.9106
# Epoch 60/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1843 - accuracy: 0.9289 - val_loss: 0.2587 - val_accuracy: 0.9136
# Epoch 61/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1822 - accuracy: 0.9284 - val_loss: 0.2522 - val_accuracy: 0.9147
# Epoch 62/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1801 - accuracy: 0.9304 - val_loss: 0.2643 - val_accuracy: 0.9103
# Epoch 63/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.1795 - accuracy: 0.9298 - val_loss: 0.2648 - val_accuracy: 0.9132
# Epoch 64/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1749 - accuracy: 0.9319 - val_loss: 0.2554 - val_accuracy: 0.9128
# Epoch 65/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1751 - accuracy: 0.9316 - val_loss: 0.2579 - val_accuracy: 0.9141
# Epoch 66/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1728 - accuracy: 0.9333 - val_loss: 0.2496 - val_accuracy: 0.9142
# Epoch 67/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1761 - accuracy: 0.9312 - val_loss: 0.2570 - val_accuracy: 0.9143
# Epoch 68/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1727 - accuracy: 0.9325 - val_loss: 0.2622 - val_accuracy: 0.9146
# Epoch 69/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1712 - accuracy: 0.9330 - val_loss: 0.2436 - val_accuracy: 0.9183
# Epoch 70/100
# 255/255 [==============================] - 17s 65ms/step - loss: 0.1679 - accuracy: 0.9347 - val_loss: 0.2493 - val_accuracy: 0.9153
# Epoch 71/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1710 - accuracy: 0.9314 - val_loss: 0.2587 - val_accuracy: 0.9148
# Epoch 72/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1663 - accuracy: 0.9351 - val_loss: 0.2519 - val_accuracy: 0.9160
# Epoch 73/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1675 - accuracy: 0.9350 - val_loss: 0.2471 - val_accuracy: 0.9196
# Epoch 74/100
# 255/255 [==============================] - 16s 64ms/step - loss: 0.1627 - accuracy: 0.9368 - val_loss: 0.2561 - val_accuracy: 0.9170
# Epoch 75/100
# 255/255 [==============================] - 16s 64ms/step - loss: 0.1629 - accuracy: 0.9363 - val_loss: 0.2564 - val_accuracy: 0.9153
# Epoch 76/100
# 255/255 [==============================] - 16s 65ms/step - loss: 0.1619 - accuracy: 0.9357 - val_loss: 0.2622 - val_accuracy: 0.9128
# Epoch 77/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1608 - accuracy: 0.9366 - val_loss: 0.2675 - val_accuracy: 0.9133
# Epoch 78/100
# 255/255 [==============================] - 17s 65ms/step - loss: 0.1592 - accuracy: 0.9377 - val_loss: 0.2558 - val_accuracy: 0.9169
# Epoch 79/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1581 - accuracy: 0.9380 - val_loss: 0.2647 - val_accuracy: 0.9152
# Epoch 80/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1608 - accuracy: 0.9374 - val_loss: 0.2526 - val_accuracy: 0.9182
# Epoch 81/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.1574 - accuracy: 0.9380 - val_loss: 0.2610 - val_accuracy: 0.9167
# Epoch 82/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.1538 - accuracy: 0.9398 - val_loss: 0.2638 - val_accuracy: 0.9173
# Epoch 83/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1554 - accuracy: 0.9394 - val_loss: 0.2611 - val_accuracy: 0.9179
# Epoch 84/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1540 - accuracy: 0.9399 - val_loss: 0.2621 - val_accuracy: 0.9148
# Epoch 85/100
# 255/255 [==============================] - 17s 65ms/step - loss: 0.1525 - accuracy: 0.9403 - val_loss: 0.2505 - val_accuracy: 0.9195
# Epoch 86/100
# 255/255 [==============================] - 17s 65ms/step - loss: 0.1520 - accuracy: 0.9409 - val_loss: 0.2510 - val_accuracy: 0.9223
# Epoch 87/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1527 - accuracy: 0.9400 - val_loss: 0.2505 - val_accuracy: 0.9184
# Epoch 88/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1517 - accuracy: 0.9415 - val_loss: 0.2605 - val_accuracy: 0.9163
# Epoch 89/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.1494 - accuracy: 0.9421 - val_loss: 0.2614 - val_accuracy: 0.9176
# Epoch 90/100
# 255/255 [==============================] - 17s 68ms/step - loss: 0.1500 - accuracy: 0.9412 - val_loss: 0.2565 - val_accuracy: 0.9200
# Epoch 91/100
# 255/255 [==============================] - 17s 67ms/step - loss: 0.1474 - accuracy: 0.9420 - val_loss: 0.2528 - val_accuracy: 0.9224
# Epoch 92/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1470 - accuracy: 0.9416 - val_loss: 0.2566 - val_accuracy: 0.9206
# Epoch 93/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1439 - accuracy: 0.9443 - val_loss: 0.2616 - val_accuracy: 0.9193
# Epoch 94/100
# 255/255 [==============================] - 16s 63ms/step - loss: 0.1477 - accuracy: 0.9420 - val_loss: 0.2549 - val_accuracy: 0.9204
# Epoch 95/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1453 - accuracy: 0.9434 - val_loss: 0.2553 - val_accuracy: 0.9223
# Epoch 96/100
# 255/255 [==============================] - 16s 64ms/step - loss: 0.1443 - accuracy: 0.9433 - val_loss: 0.2540 - val_accuracy: 0.9190
# Epoch 97/100
# 255/255 [==============================] - 17s 65ms/step - loss: 0.1436 - accuracy: 0.9438 - val_loss: 0.2487 - val_accuracy: 0.9230
# Epoch 98/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1394 - accuracy: 0.9446 - val_loss: 0.2585 - val_accuracy: 0.9209
# Epoch 99/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1443 - accuracy: 0.9434 - val_loss: 0.2605 - val_accuracy: 0.9192
# Epoch 100/100
# 255/255 [==============================] - 17s 66ms/step - loss: 0.1438 - accuracy: 0.9432 - val_loss: 0.2635 - val_accuracy: 0.9187
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 32)]          0
#
#  lstm (LSTM)                 (None, 48, 80)            36160
#
#  batch_normalization (Batch  (None, 48, 80)            320
#  Normalization)
#
#  dropout (Dropout)           (None, 48, 80)            0
#
#  lstm_1 (LSTM)               (None, 40)                19360
#
#  batch_normalization_1 (Bat  (None, 40)                160
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 40)                0
#
#  dense (Dense)               (None, 3)                 123
#
# =================================================================
# Total params: 56123 (219.23 KB)
# Trainable params: 55883 (218.29 KB)
# Non-trainable params: 240 (960.00 Byte)
# _________________________________________________________________
# 531/531 [==============================] - 5s 8ms/step

# %%
# this should work as well
print(pre.classification_metrics(y_test, y_pred, printed = True))
# Out:
# Classification Metrics:
# Accuracy: 0.92
# Precision: 0.89
# Recall: 0.89
# F1 Score: 0.89
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      9624
#            1       0.85      0.90      0.87      4129
#            2       0.84      0.83      0.83      3229
#
#     accuracy                           0.92     16982
#    macro avg       0.89      0.89      0.89     16982
# weighted avg       0.92      0.92      0.92     16982
#
# (0.9160876221881993, 0.887489305583346, 0.8929386970440628, 0.8899663843938691)

# %% [markdown]
# ### Performing Grid-search on the base arcitecture, with all inputs

# %%
outlier_threshold_list = [0.75, 1.5, 3, 'remove']
input_output_combination_1 = [
     {'input':8, 'output':8},
     {'input':24, 'output':8},
     {'input':24, 'output':24},
     {'input':48, 'output':8},
     {'input':48, 'output':24},
     {'input':48, 'output':48},
     {'input':96, 'output':8},

]
input_output_combination_2 = [
     {'input':96, 'output':24},
     {'input':96, 'output':48},
     {'input':96, 'output':96},
     {'input':192, 'output':8},
     {'input':192, 'output':24},
     {'input':192, 'output':48},
     {'input':192, 'output':96},
     {'input':192, 'output':192},
]
epoch_num = 100
bacth_size = 200
# d1 = [0.1,0.3]
# d2 = [0.05, 0.15]
d1 = 0.1
d2 = 0.05
# 
cell_size = 80

# %%
results_arr_1 = []
for outlier_threshold in outlier_threshold_list:
     for comb in input_output_combination_1:
          try:
               print('preprocessing...')
               input_window = comb['input'] #***
               output_window = comb['output'] #***

               # Initialize empty lists to store aggregated inputs and targets
               all_inputs = []
               all_targets = []

               # looping through symbols
               symbols = filtered_df['crypto_symbol'].unique()
               for s in symbols:
                    try:
                         sim_df = filtered_df[filtered_df['crypto_symbol'] == s]
                         sim_df.reset_index(inplace=True, drop=True)
                         # First Loop: Calculate intervals for each column without modifying the DataFrame
                         intervals = {}
                         for column in ['lending_rate', 'borrowing_rate', 'utilization_rate']:
                              lower, upper = pre.calculate_iqr_bounds(sim_df[column],outlier_threshold)
                              intervals[column] = {'lower_bound': lower, 'upper_bound': upper}

                         # getting the returns
                         reduced_df = sim_df.copy()
                         reduced_df['returns'] = pre.calculate_hourly_returns(reduced_df, 'date', 'close')
                         reduced_df = reduced_df[reduced_df['returns'].notna()]
                         reduced_df.reset_index(inplace=True, drop=True)

                         # Second Loop: Filter rows based on the pre-calculated intervals
                         for column in ['lending_rate', 'borrowing_rate', 'utilization_rate']:
                              lower_bound = intervals[column]['lower_bound']
                              upper_bound = intervals[column]['upper_bound']
                              # Apply filtering based on pre-calculated bounds
                              reduced_df = reduced_df[(reduced_df[column] > lower_bound) & (reduced_df[column] < upper_bound)]

                         reduced_df.reset_index(inplace=True, drop=True)

                         # MinMax scaling
                         scaler = MinMaxScaler(feature_range=(0, 1))  # Default range is (0, 1)

                         scaled_df = reduced_df.copy()
                         scaled_df['lending_rate'] = scaler.fit_transform(reduced_df[['lending_rate']])
                         scaled_df['borrowing_rate'] = scaler.fit_transform(reduced_df[['borrowing_rate']])
                         scaled_df['utilization_rate'] = scaler.fit_transform(reduced_df[['utilization_rate']])
                         scaled_df['close'] = scaler.fit_transform(reduced_df[['close']])
                         scaled_df['volume'] = scaler.fit_transform(reduced_df[['volume']])
                         scaled_df['returns'] = scaler.fit_transform(reduced_df[['returns']])

                         inputs, targets = pre.extract_valid_windows_v2(
                              scaled_df,
                              'date', 
                              input_window, output_window, 
                              input_columns, 
                              ['lending_rate','borrowing_rate']
                              )

                         # Append results from the current DataFrame
                         all_inputs.append(inputs)
                         all_targets.append(targets)
                    except Exception as e:
                         # Handle any other exceptions
                         print(f"Unexpected error in symbol {s}: {e}")

               # Concatenate all inputs and targets into single arrays
               all_inputs = np.concatenate(all_inputs, axis=0) if all_inputs else np.array([])
               all_targets = np.concatenate(all_targets, axis=0) if all_targets else np.array([])

               # Lending rate
               output_1 = all_targets[:, 0].reshape(all_targets.shape[0], 1) 
               # Borrowing rate
               output_2 = all_targets[:, 1].reshape(all_targets.shape[0], 1) 
               total_windows = output_1.shape[0] #***
               print('training ...')
               y_test, y_pred = train_v1(all_inputs, output_1, details=False)
               
               accuracy, precision, recall, f1 = pre.classification_metrics(y_test, y_pred, printed = False)

               new_row = {
                    'total_windows':total_windows,
                    'input_window':input_window,
                    'output_window':output_window, 
                    'outlier_threshold':outlier_threshold, 
                    'accuracy':accuracy, 
                    'precision':precision, 
                    'recall':recall, 
                    'f1':f1
               }
               results_arr_1.append(new_row)
               print(new_row)
               
          except Exception as e:
               print(f"Error occurred with outlier_threshold={outlier_threshold}, comb={comb}")
               print(f"Exception details: {e}")

results_1 = pd.DataFrame(results_arr_1)

# %%
results_1.to_csv('result_checkpoint_1.csv')

# %% [markdown]
# ### in parallel the scond results

# %%
results_arr_2 = []
for outlier_threshold in outlier_threshold_list:
     for comb in input_output_combination_2:
          try:
               print('preprocessing...')
               input_window = comb['input'] #***
               output_window = comb['output'] #***

               # Initialize empty lists to store aggregated inputs and targets
               all_inputs = []
               all_targets = []

               # looping through symbols
               symbols = filtered_df['crypto_symbol'].unique()
               for s in symbols:
                    try:
                         sim_df = filtered_df[filtered_df['crypto_symbol'] == s]
                         sim_df.reset_index(inplace=True, drop=True)
                         # First Loop: Calculate intervals for each column without modifying the DataFrame
                         intervals = {}
                         for column in ['lending_rate', 'borrowing_rate', 'utilization_rate']:
                              lower, upper = pre.calculate_iqr_bounds(sim_df[column],outlier_threshold)
                              intervals[column] = {'lower_bound': lower, 'upper_bound': upper}

                         # getting the returns
                         reduced_df = sim_df.copy()
                         reduced_df['returns'] = pre.calculate_hourly_returns(reduced_df, 'date', 'close')
                         reduced_df = reduced_df[reduced_df['returns'].notna()]
                         reduced_df.reset_index(inplace=True, drop=True)

                         # Second Loop: Filter rows based on the pre-calculated intervals
                         for column in ['lending_rate', 'borrowing_rate', 'utilization_rate']:
                              lower_bound = intervals[column]['lower_bound']
                              upper_bound = intervals[column]['upper_bound']
                              # Apply filtering based on pre-calculated bounds
                              reduced_df = reduced_df[(reduced_df[column] > lower_bound) & (reduced_df[column] < upper_bound)]

                         reduced_df.reset_index(inplace=True, drop=True)

                         # MinMax scaling
                         scaler = MinMaxScaler(feature_range=(0, 1))  # Default range is (0, 1)

                         scaled_df = reduced_df.copy()
                         scaled_df['lending_rate'] = scaler.fit_transform(reduced_df[['lending_rate']])
                         scaled_df['borrowing_rate'] = scaler.fit_transform(reduced_df[['borrowing_rate']])
                         scaled_df['utilization_rate'] = scaler.fit_transform(reduced_df[['utilization_rate']])
                         scaled_df['close'] = scaler.fit_transform(reduced_df[['close']])
                         scaled_df['volume'] = scaler.fit_transform(reduced_df[['volume']])
                         scaled_df['returns'] = scaler.fit_transform(reduced_df[['returns']])

                         inputs, targets = pre.extract_valid_windows_v2(
                              scaled_df,
                              'date', 
                              input_window, output_window, 
                              input_columns, 
                              ['lending_rate','borrowing_rate']
                              )

                         # Append results from the current DataFrame
                         all_inputs.append(inputs)
                         all_targets.append(targets)
                    except Exception as e:
                         # Handle any other exceptions
                         print(f"Unexpected error in symbol {s}: {e}")

               # Concatenate all inputs and targets into single arrays
               all_inputs = np.concatenate(all_inputs, axis=0) if all_inputs else np.array([])
               all_targets = np.concatenate(all_targets, axis=0) if all_targets else np.array([])

               # Lending rate
               output_1 = all_targets[:, 0].reshape(all_targets.shape[0], 1) 
               # Borrowing rate
               output_2 = all_targets[:, 1].reshape(all_targets.shape[0], 1) 
               total_windows = output_1.shape[0] #***
               print('training ...')
               y_test, y_pred = train_v1(all_inputs, output_1, details=False)
               
               accuracy, precision, recall, f1 = pre.classification_metrics(y_test, y_pred, printed = False)

               new_row = {
                    'total_windows':total_windows,
                    'input_window':input_window,
                    'output_window':output_window, 
                    'outlier_threshold':outlier_threshold, 
                    'accuracy':accuracy, 
                    'precision':precision, 
                    'recall':recall, 
                    'f1':f1
               }
               results_arr_2.append(new_row)
               print(new_row)
          except:
               print('error occured: ', outlier_threshold, comb)

results_2 = pd.DataFrame(results_arr_2)

# %%
results_2.to_csv('result_checkpoint_2.csv')

# %%
outlier_threshold_list_2 = [1.5, 3, 'remove']
input_output_combination_2 = [
     {'input':96, 'output':24},
     {'input':96, 'output':48},
     {'input':96, 'output':96},
     {'input':192, 'output':8},
     {'input':192, 'output':24},
     {'input':192, 'output':48},
     {'input':192, 'output':96},
     {'input':192, 'output':192},
]

# %%
results_arr_3 = []
for outlier_threshold in outlier_threshold_list_2:
     for comb in input_output_combination_2:
          try:
               print('preprocessing...')
               input_window = comb['input'] #***
               output_window = comb['output'] #***

               # Initialize empty lists to store aggregated inputs and targets
               all_inputs = []
               all_targets = []

               # looping through symbols
               symbols = filtered_df['crypto_symbol'].unique()
               for s in symbols:
                    try:
                         sim_df = filtered_df[filtered_df['crypto_symbol'] == s]
                         sim_df.reset_index(inplace=True, drop=True)
                         # First Loop: Calculate intervals for each column without modifying the DataFrame
                         intervals = {}
                         for column in ['lending_rate', 'borrowing_rate', 'utilization_rate']:
                              lower, upper = pre.calculate_iqr_bounds(sim_df[column],outlier_threshold)
                              intervals[column] = {'lower_bound': lower, 'upper_bound': upper}

                         # getting the returns
                         reduced_df = sim_df.copy()
                         reduced_df['returns'] = pre.calculate_hourly_returns(reduced_df, 'date', 'close')
                         reduced_df = reduced_df[reduced_df['returns'].notna()]
                         reduced_df.reset_index(inplace=True, drop=True)

                         # Second Loop: Filter rows based on the pre-calculated intervals
                         for column in ['lending_rate', 'borrowing_rate', 'utilization_rate']:
                              lower_bound = intervals[column]['lower_bound']
                              upper_bound = intervals[column]['upper_bound']
                              # Apply filtering based on pre-calculated bounds
                              reduced_df = reduced_df[(reduced_df[column] > lower_bound) & (reduced_df[column] < upper_bound)]

                         reduced_df.reset_index(inplace=True, drop=True)

                         # MinMax scaling
                         scaler = MinMaxScaler(feature_range=(0, 1))  # Default range is (0, 1)

                         scaled_df = reduced_df.copy()
                         scaled_df['lending_rate'] = scaler.fit_transform(reduced_df[['lending_rate']])
                         scaled_df['borrowing_rate'] = scaler.fit_transform(reduced_df[['borrowing_rate']])
                         scaled_df['utilization_rate'] = scaler.fit_transform(reduced_df[['utilization_rate']])
                         scaled_df['close'] = scaler.fit_transform(reduced_df[['close']])
                         scaled_df['volume'] = scaler.fit_transform(reduced_df[['volume']])
                         scaled_df['returns'] = scaler.fit_transform(reduced_df[['returns']])

                         inputs, targets = pre.extract_valid_windows_v2(
                              scaled_df,
                              'date', 
                              input_window, output_window, 
                              input_columns, 
                              ['lending_rate','borrowing_rate']
                              )

                         # Append results from the current DataFrame
                         if len(inputs.shape) == 3:
                              all_inputs.append(inputs)
                              all_targets.append(targets)
                    except Exception as e:
                         # Handle any other exceptions
                         print(f"Unexpected error in symbol {s}: {e}")

               # Concatenate all inputs and targets into single arrays
               all_inputs = np.concatenate(all_inputs, axis=0) if all_inputs else np.array([])
               all_targets = np.concatenate(all_targets, axis=0) if all_targets else np.array([])

               # Lending rate
               output_1 = all_targets[:, 0].reshape(all_targets.shape[0], 1) 
               # Borrowing rate
               output_2 = all_targets[:, 1].reshape(all_targets.shape[0], 1) 
               total_windows = output_1.shape[0] #***
               print('training ...')
               y_test, y_pred = train_v1(all_inputs, output_1, details=False)
               
               accuracy, precision, recall, f1 = pre.classification_metrics(y_test, y_pred, printed = False)

               new_row = {
                    'total_windows':total_windows,
                    'input_window':input_window,
                    'output_window':output_window, 
                    'outlier_threshold':outlier_threshold, 
                    'accuracy':accuracy, 
                    'precision':precision, 
                    'recall':recall, 
                    'f1':f1
               }
               results_arr_3.append(new_row)
               print(new_row)
               
          except Exception as e:
               print(f"Error occurred with outlier_threshold={outlier_threshold}, comb={comb}")
               print(f"Exception details: {e}")

results_3 = pd.DataFrame(results_arr_3)
# Out:
# preprocessing...
# training ...
# WARNING:tensorflow:From c:\Users\hgnik\anaconda3\Lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\hgnik\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\hgnik\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 361/361 [==============================] - 6s 13ms/step
# {'total_windows': 57703, 'input_window': 96, 'output_window': 24, 'outlier_threshold': 1.5, 'accuracy': 0.941772809981804, 'precision': 0.9102707827214775, 'recall': 0.905662887849609, 'f1': 0.9077584993383985}
# preprocessing...
# training ...
# 311/311 [==============================] - 5s 14ms/step
# {'total_windows': 49631, 'input_window': 96, 'output_window': 48, 'outlier_threshold': 1.5, 'accuracy': 0.9615190893522716, 'precision': 0.9467083387595263, 'recall': 0.9443150294252839, 'f1': 0.945412410174525}
# preprocessing...
# training ...
# 241/241 [==============================] - 4s 13ms/step
# {'total_windows': 38559, 'input_window': 96, 'output_window': 96, 'outlier_threshold': 1.5, 'accuracy': 0.9712136929460581, 'precision': 0.9653892586529186, 'recall': 0.9622964352261674, 'f1': 0.9638190358047286}
# preprocessing...
# training ...
# 233/233 [==============================] - 9s 34ms/step
# {'total_windows': 37163, 'input_window': 192, 'output_window': 8, 'outlier_threshold': 1.5, 'accuracy': 0.9487420960581192, 'precision': 0.8300984221086468, 'recall': 0.8081234118792328, 'f1': 0.8185260319504978}
# preprocessing...
# training ...
# 217/217 [==============================] - 9s 35ms/step
# {'total_windows': 34608, 'input_window': 192, 'output_window': 24, 'outlier_threshold': 1.5, 'accuracy': 0.9601271308870268, 'precision': 0.9158747666140407, 'recall': 0.9207565198051219, 'f1': 0.9182963287319494}
# preprocessing...
# training ...
# 196/196 [==============================] - 8s 34ms/step
# {'total_windows': 31279, 'input_window': 192, 'output_window': 48, 'outlier_threshold': 1.5, 'accuracy': 0.9683503836317136, 'precision': 0.9500150559965541, 'recall': 0.9490280784830132, 'f1': 0.9494474523668309}
# preprocessing...
# training ...
# 163/163 [==============================] - 5s 27ms/step
# {'total_windows': 25978, 'input_window': 192, 'output_window': 96, 'outlier_threshold': 1.5, 'accuracy': 0.976905311778291, 'precision': 0.9662851059852926, 'recall': 0.9677504246871808, 'f1': 0.9670093823207546}
# preprocessing...
# training ...
# 115/115 [==============================] - 4s 27ms/step
# {'total_windows': 18355, 'input_window': 192, 'output_window': 192, 'outlier_threshold': 1.5, 'accuracy': 0.9871969490602016, 'precision': 0.9833998205321078, 'recall': 0.9844421971565266, 'f1': 0.9839178326395256}
# preprocessing...
# training ...
# 418/418 [==============================] - 7s 15ms/step
# {'total_windows': 66758, 'input_window': 96, 'output_window': 24, 'outlier_threshold': 3, 'accuracy': 0.9373127621330137, 'precision': 0.89834536891768, 'recall': 0.9014484852672089, 'f1': 0.8998469113490614}
# preprocessing...
# training ...
# 362/362 [==============================] - 6s 15ms/step
# {'total_windows': 57787, 'input_window': 96, 'output_window': 48, 'outlier_threshold': 3, 'accuracy': 0.9591624848589722, 'precision': 0.9412544883557792, 'recall': 0.9412196084354777, 'f1': 0.941224084024281}
# preprocessing...
# training ...
# 287/287 [==============================] - 5s 15ms/step
# {'total_windows': 45787, 'input_window': 96, 'output_window': 96, 'outlier_threshold': 3, 'accuracy': 0.9693164446385674, 'precision': 0.9609471549174932, 'recall': 0.9580520440484227, 'f1': 0.9594580213143954}
# preprocessing...
# training ...
# 277/277 [==============================] - 9s 28ms/step
# {'total_windows': 44275, 'input_window': 192, 'output_window': 8, 'outlier_threshold': 3, 'accuracy': 0.9479390175042349, 'precision': 0.8204139488825453, 'recall': 0.8186070956217856, 'f1': 0.8193195160921389}
# preprocessing...
# training ...
# 260/260 [==============================] - 8s 29ms/step
# {'total_windows': 41495, 'input_window': 192, 'output_window': 24, 'outlier_threshold': 3, 'accuracy': 0.9568622725629594, 'precision': 0.9196781867733509, 'recall': 0.9071395689913726, 'f1': 0.9130826420933752}
# preprocessing...
# training ...
# 237/237 [==============================] - 8s 29ms/step
# {'total_windows': 37844, 'input_window': 192, 'output_window': 48, 'outlier_threshold': 3, 'accuracy': 0.971726780288017, 'precision': 0.9513767550915326, 'recall': 0.947817422353774, 'f1': 0.949581127328381}
# preprocessing...
# training ...
# 201/201 [==============================] - 7s 30ms/step
# {'total_windows': 32150, 'input_window': 192, 'output_window': 96, 'outlier_threshold': 3, 'accuracy': 0.9741835147744946, 'precision': 0.9566087614405338, 'recall': 0.9606880864283345, 'f1': 0.9586270266464858}
# preprocessing...
# training ...
# 150/150 [==============================] - 5s 29ms/step
# {'total_windows': 23998, 'input_window': 192, 'output_window': 192, 'outlier_threshold': 3, 'accuracy': 0.9852083333333334, 'precision': 0.9799397991274007, 'recall': 0.9743096630948357, 'f1': 0.9770504305589357}
# preprocessing...
# training ...
# 936/936 [==============================] - 16s 16ms/step
# {'total_windows': 149656, 'input_window': 96, 'output_window': 24, 'outlier_threshold': 'remove', 'accuracy': 0.9525591340371509, 'precision': 0.8968356885966305, 'recall': 0.9011723523959745, 'f1': 0.8989352798688776}
# preprocessing...
# training ...
# 842/842 [==============================] - 14s 16ms/step
# {'total_windows': 134647, 'input_window': 96, 'output_window': 48, 'outlier_threshold': 'remove', 'accuracy': 0.9662829558113628, 'precision': 0.936972264910645, 'recall': 0.9326692133852249, 'f1': 0.9347260803621728}
# preprocessing...
# training ...
# 706/706 [==============================] - 13s 17ms/step
# {'total_windows': 112906, 'input_window': 96, 'output_window': 96, 'outlier_threshold': 'remove', 'accuracy': 0.9760428659994687, 'precision': 0.9596744222326249, 'recall': 0.9561366772748925, 'f1': 0.9578679565980401}
# preprocessing...
# training ...
# 688/688 [==============================] - 23s 32ms/step
# {'total_windows': 110038, 'input_window': 192, 'output_window': 8, 'outlier_threshold': 'remove', 'accuracy': 0.9581515812431843, 'precision': 0.8020179309078707, 'recall': 0.7922617460906197, 'f1': 0.7967715611153214}
# preprocessing...
# training ...
# 654/654 [==============================] - 22s 33ms/step
# {'total_windows': 104624, 'input_window': 192, 'output_window': 24, 'outlier_threshold': 'remove', 'accuracy': 0.9680764635603345, 'precision': 0.8971015897994524, 'recall': 0.9087909364505836, 'f1': 0.9028462509274963}
# preprocessing...
# training ...
# 609/609 [==============================] - 19s 29ms/step
# {'total_windows': 97339, 'input_window': 192, 'output_window': 48, 'outlier_threshold': 'remove', 'accuracy': 0.9750873227861105, 'precision': 0.9424385566048287, 'recall': 0.9373676410949449, 'f1': 0.9397756411710704}
# preprocessing...
# training ...
# 534/534 [==============================] - 17s 30ms/step
# {'total_windows': 85404, 'input_window': 192, 'output_window': 96, 'outlier_threshold': 'remove', 'accuracy': 0.9785726830981792, 'precision': 0.9561333871278284, 'recall': 0.9536520013504289, 'f1': 0.9548762500311826}
# preprocessing...
# training ...
# 420/420 [==============================] - 14s 30ms/step
# {'total_windows': 67043, 'input_window': 192, 'output_window': 192, 'outlier_threshold': 'remove', 'accuracy': 0.9827727645611156, 'precision': 0.9724387142760542, 'recall': 0.964563765945817, 'f1': 0.9684318005980411}

# %%
results_3.to_csv('result_checkpoint_3.csv')

# %%
results_concatenated_arr = [
  {
    "total_windows": 161498,
    "input_window": 8,
    "output_window": 8,
    "outlier_threshold": 0.75,
    "accuracy": 0.805015479876161,
    "precision": 0.7284011900080548,
    "recall": 0.7190092300602431,
    "f1": 0.7231271786440341
  },
  {
    "total_windows": 124197,
    "input_window": 24,
    "output_window": 8,
    "outlier_threshold": 0.75,
    "accuracy": 0.8478260869565217,
    "precision": 0.7646140580814885,
    "recall": 0.7679676838027246,
    "f1": 0.7662746885640611
  },
  {
    "total_windows": 100134,
    "input_window": 24,
    "output_window": 24,
    "outlier_threshold": 0.75,
    "accuracy": 0.9088230888300793,
    "precision": 0.8849807940783556,
    "recall": 0.889388405908531,
    "f1": 0.8870731188952945
  },
  {
    "total_windows": 91103,
    "input_window": 48,
    "output_window": 8,
    "outlier_threshold": 0.75,
    "accuracy": 0.8783272048734976,
    "precision": 0.7825322435256802,
    "recall": 0.7775991998766544,
    "f1": 0.7800197978434812
  },
  {
    "total_windows": 77235,
    "input_window": 48,
    "output_window": 24,
    "outlier_threshold": 0.75,
    "accuracy": 0.923350812455493,
    "precision": 0.8929993454627488,
    "recall": 0.895331808169141,
    "f1": 0.8941578036607063
  },
  {
    "total_windows": 179161,
    "input_window": 8,
    "output_window": 8,
    "outlier_threshold": 1.5,
    "accuracy": 0.7946027404906092,
    "precision": 0.7178000873108198,
    "recall": 0.7154863783565976,
    "f1": 0.7166077021522463
  },
  {
    "total_windows": 137341,
    "input_window": 24,
    "output_window": 8,
    "outlier_threshold": 1.5,
    "accuracy": 0.8408751683716189,
    "precision": 0.7593802654542022,
    "recall": 0.7539271600604186,
    "f1": 0.7565955031191778
  },
  {
    "total_windows": 110558,
    "input_window": 24,
    "output_window": 24,
    "outlier_threshold": 1.5,
    "accuracy": 0.9046671490593343,
    "precision": 0.8848388380805025,
    "recall": 0.88546197918045,
    "f1": 0.8851292469253433
  },
  {
    "total_windows": 100542,
    "input_window": 48,
    "output_window": 8,
    "outlier_threshold": 1.5,
    "accuracy": 0.8718484260778756,
    "precision": 0.7786834923730629,
    "recall": 0.7767844231011746,
    "f1": 0.7775423808435405
  },
  {
    "total_windows": 84910,
    "input_window": 48,
    "output_window": 24,
    "outlier_threshold": 1.5,
    "accuracy": 0.9157931927923684,
    "precision": 0.890195486808082,
    "recall": 0.8871248905370995,
    "f1": 0.8885651088239648
  },
  {
    "total_windows": 68870,
    "input_window": 48,
    "output_window": 48,
    "outlier_threshold": 1.5,
    "accuracy": 0.9468563961086104,
    "precision": 0.9328646637688895,
    "recall": 0.9337874166962549,
    "f1": 0.9333236753739161
  },
  {
    "total_windows": 64776,
    "input_window": 96,
    "output_window": 8,
    "outlier_threshold": 1.5,
    "accuracy": 0.9092312442111763,
    "precision": 0.7968661027685858,
    "recall": 0.792474382288364,
    "f1": 0.7946096168183244
  },
  {
    "total_windows": 201229,
    "input_window": 8,
    "output_window": 8,
    "outlier_threshold": 3,
    "accuracy": 0.7776673458231874,
    "precision": 0.7028578382743317,
    "recall": 0.6961036363974299,
    "f1": 0.6992636285647423
  },
  {
    "total_windows": 155219,
    "input_window": 24,
    "output_window": 8,
    "outlier_threshold": 3,
    "accuracy": 0.8331722716144827,
    "precision": 0.7517576293640871,
    "recall": 0.7520766111176863,
    "f1": 0.7516185883284967
  },
  {
    "total_windows": 125552,
    "input_window": 24,
    "output_window": 24,
    "outlier_threshold": 3,
    "accuracy": 0.9035084226036398,
    "precision": 0.8822501243041315,
    "recall": 0.8821800999157322,
    "f1": 0.8820922198883901
  },
  {
    "total_windows": 114421,
    "input_window": 48,
    "output_window": 8,
    "outlier_threshold": 3,
    "accuracy": 0.8680358313305658,
    "precision": 0.7739353650446459,
    "recall": 0.7689067692072514,
    "f1": 0.7713383152131982
  },
  {
    "total_windows": 97078,
    "input_window": 48,
    "output_window": 24,
    "outlier_threshold": 3,
    "accuracy": 0.9163061392665842,
    "precision": 0.8858487505000618,
    "recall": 0.8895175900463346,
    "f1": 0.8876587406951829
  },
  {
    "total_windows": 79137,
    "input_window": 48,
    "output_window": 48,
    "outlier_threshold": 3,
    "accuracy": 0.9506570634318928,
    "precision": 0.9382847813878942,
    "recall": 0.9375977426717453,
    "f1": 0.9379373966116603
  },
  {
    "total_windows": 74605,
    "input_window": 96,
    "output_window": 8,
    "outlier_threshold": 3,
    "accuracy": 0.9071778030963072,
    "precision": 0.8002947754064235,
    "recall": 0.7807430599581292,
    "f1": 0.789916056104009
  },
  {
    "total_windows": 327875,
    "input_window": 8,
    "output_window": 8,
    "outlier_threshold": "remove",
    "accuracy": 0.8200686237133054,
    "precision": 0.7066615593219886,
    "recall": 0.6960312162211983,
    "f1": 0.700878606522123
  },
  {
    "total_windows": 273290,
    "input_window": 24,
    "output_window": 8,
    "outlier_threshold": "remove",
    "accuracy": 0.8605876541402905,
    "precision": 0.738147433332408,
    "recall": 0.742869896290912,
    "f1": 0.7404472312905543
  },
  {
    "total_windows": 235083,
    "input_window": 24,
    "output_window": 24,
    "outlier_threshold": "remove",
    "accuracy": 0.9186464470297977,
    "precision": 0.874485319125894,
    "recall": 0.8784571710543391,
    "f1": 0.8763867778181978
  },
  {
    "total_windows": 220131,
    "input_window": 48,
    "output_window": 8,
    "outlier_threshold": "remove",
    "accuracy": 0.8924523587798396,
    "precision": 0.7571354256846973,
    "recall": 0.7568231267134687,
    "f1": 0.7568448751184067
  },
  {
    "total_windows": 195877,
    "input_window": 48,
    "output_window": 24,
    "outlier_threshold": "remove",
    "accuracy": 0.9319991831733715,
    "precision": 0.881989144528569,
    "recall": 0.8843984070060519,
    "f1": 0.8831319284125021
  },
  {
    "total_windows": 169235,
    "input_window": 48,
    "output_window": 48,
    "outlier_threshold": "remove",
    "accuracy": 0.9563624545749992,
    "precision": 0.9308015465456978,
    "recall": 0.9283919386004099,
    "f1": 0.9295685481353487
  },
  {
    "total_windows": 162173,
    "input_window": 96,
    "output_window": 8,
    "outlier_threshold": "remove",
    "accuracy": 0.9324495144134423,
    "precision": 0.7899275540037598,
    "recall": 0.7907096232200033,
    "f1": 0.7897159132510603
  },
  {
    "total_windows": 66758,
    "input_window": 96,
    "output_window": 24,
    "outlier_threshold": 3,
    "accuracy": 0.9397843019772318,
    "precision": 0.899019400087241,
    "recall": 0.9050565919834498,
    "f1": 0.9020000998565806
  },
  {
    "total_windows": 53227,
    "input_window": 96,
    "output_window": 24,
    "outlier_threshold": 0.75,
    "accuracy": 0.9418560961863611,
    "precision": 0.89923975048056,
    "recall": 0.906111031300608,
    "f1": 0.9026333239536019
  },
  {
    "total_windows": 45984,
    "input_window": 96,
    "output_window": 48,
    "outlier_threshold": 0.75,
    "accuracy": 0.9621615744264435,
    "precision": 0.9444138041778123,
    "recall": 0.9428562411454987,
    "f1": 0.9436259704754105
  },
  {
    "total_windows": 35866,
    "input_window": 96,
    "output_window": 96,
    "outlier_threshold": 0.75,
    "accuracy": 0.9669640367995539,
    "precision": 0.955762053714996,
    "recall": 0.9559345777197411,
    "f1": 0.9558476506983267
  },
  {
    "total_windows": 34585,
    "input_window": 192,
    "output_window": 8,
    "outlier_threshold": 0.75,
    "accuracy": 0.9491108862223507,
    "precision": 0.8205994545003411,
    "recall": 0.8090738530689082,
    "f1": 0.8143141985585783
  },
  {
    "total_windows": 32247,
    "input_window": 192,
    "output_window": 24,
    "outlier_threshold": 0.75,
    "accuracy": 0.958139534883721,
    "precision": 0.9117928158005415,
    "recall": 0.9227112038818134,
    "f1": 0.9170946758488622
  },
  {
    "total_windows": 29222,
    "input_window": 192,
    "output_window": 48,
    "outlier_threshold": 0.75,
    "accuracy": 0.9714285714285714,
    "precision": 0.9489725231419216,
    "recall": 0.9501371711916632,
    "f1": 0.949553715257267
  },
  {
    "total_windows": 24302,
    "input_window": 192,
    "output_window": 96,
    "outlier_threshold": 0.75,
    "accuracy": 0.9753137214564904,
    "precision": 0.9658347638374188,
    "recall": 0.9591429921629375,
    "f1": 0.962380111113
  },
  {
    "total_windows": 17133,
    "input_window": 192,
    "output_window": 192,
    "outlier_threshold": 0.75,
    "accuracy": 0.983659177122848,
    "precision": 0.977814518176308,
    "recall": 0.9779319455265704,
    "f1": 0.9778683567235623
  }
]

results_concatenated = pd.DataFrame(results_concatenated_arr)
results_concatenated
# Out:
#     total_windows  input_window  output_window outlier_threshold  accuracy  \
# 0          161498             8              8              0.75  0.805015
# 1          124197            24              8              0.75  0.847826
# 2          100134            24             24              0.75  0.908823
# 3           91103            48              8              0.75  0.878327
# 4           77235            48             24              0.75  0.923351
# 5          179161             8              8               1.5  0.794603
# 6          137341            24              8               1.5  0.840875
# 7          110558            24             24               1.5  0.904667
# 8          100542            48              8               1.5  0.871848
# 9           84910            48             24               1.5  0.915793
# 10          68870            48             48               1.5  0.946856
# 11          64776            96              8               1.5  0.909231
# 12         201229             8              8                 3  0.777667
# 13         155219            24              8                 3  0.833172
# 14         125552            24             24                 3  0.903508
# 15         114421            48              8                 3  0.868036
# 16          97078            48             24                 3  0.916306
# 17          79137            48             48                 3  0.950657
# 18          74605            96              8                 3  0.907178
# 19         327875             8              8            remove  0.820069
# 20         273290            24              8            remove  0.860588
# 21         235083            24             24            remove  0.918646
# 22         220131            48              8            remove  0.892452
# 23         195877            48             24            remove  0.931999
# 24         169235            48             48            remove  0.956362
# 25         162173            96              8            remove  0.932450
# 26          66758            96             24                 3  0.939784
# 27          53227            96             24              0.75  0.941856
# 28          45984            96             48              0.75  0.962162
# 29          35866            96             96              0.75  0.966964
# 30          34585           192              8              0.75  0.949111
# 31          32247           192             24              0.75  0.958140
# 32          29222           192             48              0.75  0.971429
# 33          24302           192             96              0.75  0.975314
# 34          17133           192            192              0.75  0.983659
#
#     precision    recall        f1
# 0    0.728401  0.719009  0.723127
# 1    0.764614  0.767968  0.766275
# 2    0.884981  0.889388  0.887073
# 3    0.782532  0.777599  0.780020
# 4    0.892999  0.895332  0.894158
# 5    0.717800  0.715486  0.716608
# 6    0.759380  0.753927  0.756596
# 7    0.884839  0.885462  0.885129
# 8    0.778683  0.776784  0.777542
# 9    0.890195  0.887125  0.888565
# 10   0.932865  0.933787  0.933324
# 11   0.796866  0.792474  0.794610
# 12   0.702858  0.696104  0.699264
# 13   0.751758  0.752077  0.751619
# 14   0.882250  0.882180  0.882092
# 15   0.773935  0.768907  0.771338
# 16   0.885849  0.889518  0.887659
# 17   0.938285  0.937598  0.937937
# 18   0.800295  0.780743  0.789916
# 19   0.706662  0.696031  0.700879
# 20   0.738147  0.742870  0.740447
# 21   0.874485  0.878457  0.876387
# 22   0.757135  0.756823  0.756845
# 23   0.881989  0.884398  0.883132
# 24   0.930802  0.928392  0.929569
# 25   0.789928  0.790710  0.789716
# 26   0.899019  0.905057  0.902000
# 27   0.899240  0.906111  0.902633
# 28   0.944414  0.942856  0.943626
# 29   0.955762  0.955935  0.955848
# 30   0.820599  0.809074  0.814314
# 31   0.911793  0.922711  0.917095
# 32   0.948973  0.950137  0.949554
# 33   0.965835  0.959143  0.962380
# 34   0.977815  0.977932  0.977868

# %%
results_concatenated.to_excel('results_concatenated.xlsx')

# %%
# Calculate correlation between length and accuracy
correlation = results_concatenated['total_windows'].corr(results_concatenated['accuracy'])
print("Correlation:", correlation)

# Create a scatter plot with a regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='total_windows', y='accuracy', data=results_concatenated, line_kws={'color': 'red'})
plt.title(f"Total Windows vs. Accuracy (Correlation: {correlation:.2f})")
plt.xlabel('Total Windows')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Correlation: -0.6495605621661548

# %%
# Calculate correlation between input_window and accuracy
correlation = results_concatenated['input_window'].corr(results_concatenated['accuracy'])
print("Correlation:", correlation)

# Create a scatter plot with a regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='input_window', y='accuracy', data=results_concatenated, line_kws={'color': 'red'})
plt.title(f"input_window vs. Accuracy (Correlation: {correlation:.2f})")
plt.xlabel('input_window')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Correlation: 0.7165450560628177

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Calculate correlation between output_window and accuracy
correlation = results_concatenated['output_window'].corr(results_concatenated['accuracy'])
print("Correlation:", correlation)

# Create a scatter plot with a regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='output_window', y='accuracy', data=results_concatenated, line_kws={'color': 'red'})
plt.title(f"output_window vs. Accuracy (Correlation: {correlation:.2f})")
plt.xlabel('output_window')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Correlation: 0.5941822422928894

# %% [markdown]
# ### End of Notebook
